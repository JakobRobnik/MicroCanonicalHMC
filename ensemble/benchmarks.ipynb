# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image, display

targets = ['Banana', 'ICG', 'GC', 'brownian', 'IRT', 'SV']

for i in [5, ]:

    name = targets[i]
    print(name)
    display(Image(filename='../img/ensemble/adjusted/'+name+'.png'))
# Out:
# SV
